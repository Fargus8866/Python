# %% [markdown]
# <a href="https://colab.research.google.com/github/Fargus8866/Python/blob/pandas/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://github.com/anvarnarz/praktikum_datasets/blob/main/netflix.xlsx?raw=true"
df=pd.read_excel(url, index_col='title')
df
# Out:
#                         rating  \
# title
# White Chicks             PG-13
# Lucky Number Slevin          R
# Grey's Anatomy           TV-14
# Prison Break             TV-14
# How I Met Your Mother    TV-PG
# ...                        ...
# The BFG                     PG
# The Secret Life of Pets     PG
# Precious Puppies          TV-G
# Beary Tales               TV-G
# Growing Up Wild              G
#
#                                                                ratingLevel  \
# title
# White Chicks             crude and sexual humor, language and some drug...
# Lucky Number Slevin      strong violence, sexual content and adult lang...
# Grey's Anatomy           Parents strongly cautioned. May be unsuitable ...
# Prison Break             Parents strongly cautioned. May be unsuitable ...
# How I Met Your Mother    Parental guidance suggested. May not be suitab...
# ...                                                                    ...
# ...

# %%
df.to_excel("malumot.xlsx",columns=['rating','ratingLevel','release year','user rating size'])

# %%
df1=pd.read_html("https://ru.wikipedia.org/wiki/%D0%A3%D0%B7%D0%B1%D0%B5%D0%BA%D0%B8%D1%81%D1%82%D0%B0%D0%BD")

# %%
df1[2]
# Out:
#     Номер на карте           Русское название  \
# 0                1                    Ташкент
# 1               14  Республика Каракалпакстан
# 2                2        Андижанская область
# 3                3          Бухарская область
# 4                5         Джизакская область
# 5                8    Кашкадарьинская область
# 6                7         Навоийская область
# 7                6       Наманганская область
# 8                9      Самаркандская область
# 9               11   Сурхандарьинская область
# 10              10      Сырдарьинская область
# 11              12        Ташкентская область
# 12               4         Ферганская область
# 13              13         Хорезмская область
#
#                                    Узбекское название  \
# 0                                    Toshkent Тошкент
# 1   Qoraqalpog’iston Respublikasi Қорақалпоғистон ...
# 2                    Andijon viloyati Андижон вилояти
# ...

# %%
import requests

# Where USD is the base currency you want to use
url = 'https://v6.exchangerate-api.com/v6/bed27ac1374dad7192fcfcd9/pair/EUR/USD'

# Making our request
response = requests.get(url)
data = response.json()

# Your JSON object
data
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1707350401,
#  'time_last_update_utc': 'Thu, 08 Feb 2024 00:00:01 +0000',
#  'time_next_update_unix': 1707436801,
#  'time_next_update_utc': 'Fri, 09 Feb 2024 00:00:01 +0000',
#  'base_code': 'EUR',
#  'target_code': 'USD',
#  'conversion_rate': 1.0771}

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %%
data[2]
# Out:
#                                              Tashkent  \
#                           Climate chart (explanation)
# 0   J F M A M J J A S O N D  55  6 −3  47  8 −2  7...
# 1                                                   J
# 2                                            55  6 −3
# 3          █ Average max. and min. temperatures in °C
# 4                        █ Precipitation totals in mm
# 5                                     Source: WMO[49]
# 6   Imperial conversion JFMAMJJASOND  2.1  42 26  ...
# 7                                 Imperial conversion
# 8                                                   J
# 9                                          2.1  42 26
# 10         █ Average max. and min. temperatures in °F
# 11                   █ Precipitation totals in inches
#
#                             Unnamed: 1_level_0  \
#                             Unnamed: 1_level_1
# 0                                          NaN
# 1                                            F
# ...
