# %% [markdown]
# <a href="https://colab.research.google.com/github/Fargus8866/Python/blob/pandas/SQLdan_o'qish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql
from pprint import pprint as print

# %%
# !unzip "chinook.zip"
# Out:
# Archive:  chinook.zip
#   inflating: chinook.db

# %%
db =sql.connect("chinook.db")
cursor = db.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
cursor.execute("SELECT COUNT (*) FROM customers")
cursor.fetchone()
# Out:
# (59,)

# %%
cursor.execute("PRAGMA table_info(customers);")
cursor.fetchall()
# Out:
# [(0, 'CustomerId', 'INTEGER', 1, None, 1),
#  (1, 'FirstName', 'NVARCHAR(40)', 1, None, 0),
#  (2, 'LastName', 'NVARCHAR(20)', 1, None, 0),
#  (3, 'Company', 'NVARCHAR(80)', 0, None, 0),
#  (4, 'Address', 'NVARCHAR(70)', 0, None, 0),
#  (5, 'City', 'NVARCHAR(40)', 0, None, 0),
#  (6, 'State', 'NVARCHAR(40)', 0, None, 0),
#  (7, 'Country', 'NVARCHAR(40)', 0, None, 0),
#  (8, 'PostalCode', 'NVARCHAR(10)', 0, None, 0),
#  (9, 'Phone', 'NVARCHAR(24)', 0, None, 0),
#  (10, 'Fax', 'NVARCHAR(24)', 0, None, 0),
#  (11, 'Email', 'NVARCHAR(60)', 1, None, 0),
#  (12, 'SupportRepId', 'INTEGER', 0, None, 0)]

# %%
query="SELECT * FROM customers"
df=pd.read_sql(query,db,index_col='CustomerId')

# %%
df.head(3)
# Out:
#            FirstName   LastName  \
# CustomerId
# 1               Luís  Gonçalves
# 2             Leonie     Köhler
# 3           François   Tremblay
#
#                                                      Company  \
# CustomerId
# 1           Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                       None
# 3                                                       None
#
#                                     Address                 City State  \
# CustomerId
# 1           Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP
# 2                   Theodor-Heuss-Straße 34            Stuttgart  None
# 3                         1498 rue Bélanger             Montréal    QC
#
#             Country PostalCode               Phone                 Fax  \
# CustomerId
# 1            Brazil  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 2           Germany      70174    +49 0711 2842222                None
# ...

# %%
query="SELECT FirstName,LastName,City,Country,Phone,Email FROM customers"
df1=pd.read_sql(query,db)

# %%
df1.head()
# Out:
#    FirstName     LastName                 City         Country  \
# 0       Luís    Gonçalves  São José dos Campos          Brazil
# 1     Leonie       Köhler            Stuttgart         Germany
# 2   François     Tremblay             Montréal          Canada
# 3      Bjørn       Hansen                 Oslo          Norway
# 4  František  Wichterlová               Prague  Czech Republic
#
#                 Phone                     Email
# 0  +55 (12) 3923-5555      luisg@embraer.com.br
# 1    +49 0711 2842222     leonekohler@surfeu.de
# 2   +1 (514) 721-4711       ftremblay@gmail.com
# 3     +47 22 44 22 22     bjorn.hansen@yahoo.no
# 4    +420 2 4172 5555  frantisekw@jetbrains.com

# %%
query="SELECT FirstName,LastName,City,Country,Phone,Email FROM customers ORDER BY LastName"
df2=pd.read_sql(query,db)
df2.head()
# Out:
#   FirstName LastName            City Country               Phone  \
# 0   Roberto  Almeida  Rio de Janeiro  Brazil  +55 (21) 2271-7000
# 1     Julia  Barnett  Salt Lake City     USA   +1 (801) 531-7272
# 2   Camille  Bernard           Paris  France  +33 01 49 70 65 65
# 3  Michelle   Brooks        New York     USA   +1 (212) 221-3546
# 4    Robert    Brown         Toronto  Canada   +1 (416) 363-8888
#
#                            Email
# 0  roberto.almeida@riotur.gov.br
# 1            jubarnett@gmail.com
# 2       camille.bernard@yahoo.fr
# 3              michelleb@aol.com
# 4               robbrown@shaw.ca

# %%
query = "SELECT DISTINCT Country FROM customers"
cursor.execute(query)
cursor.fetchall()
# Out:
# [('Brazil',),
#  ('Germany',),
#  ('Canada',),
#  ('Norway',),
#  ('Czech Republic',),
#  ('Austria',),
#  ('Belgium',),
#  ('Denmark',),
#  ('USA',),
#  ('Portugal',),
#  ('France',),
#  ('Finland',),
#  ('Hungary',),
#  ('Ireland',),
#  ('Italy',),
#  ('Netherlands',),
#  ('Poland',),
#  ('Spain',),
#  ('Sweden',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Argentina',),
#  ('Chile',),
#  ('India',)]

# %%
countries = pd.read_sql(query, db)
countries.head()
# Out:
#           Country
# 0          Brazil
# 1         Germany
# 2          Canada
# 3          Norway
# 4  Czech Republic

# %%
query = 'SELECT CustomerId, FirstName,LastName,City,Country,Phone,Email FROM customers WHERE country="Brazil" OR country="USA"'
df = pd.read_sql(query, db, index_col="CustomerId")

# %%
df
# Out:
#             FirstName    LastName                 City Country  \
# CustomerId
# 1                Luís   Gonçalves  São José dos Campos  Brazil
# 10            Eduardo     Martins            São Paulo  Brazil
# 11          Alexandre       Rocha            São Paulo  Brazil
# 12            Roberto     Almeida       Rio de Janeiro  Brazil
# 13           Fernanda       Ramos             Brasília  Brazil
# 16              Frank      Harris        Mountain View     USA
# 17               Jack       Smith              Redmond     USA
# 18           Michelle      Brooks             New York     USA
# 19                Tim       Goyer            Cupertino     USA
# 20                Dan      Miller        Mountain View     USA
# 21              Kathy       Chase                 Reno     USA
# 22            Heather     Leacock              Orlando     USA
# 23               John      Gordon               Boston     USA
# 24              Frank     Ralston              Chicago     USA
# ...
